# %% [markdown]
# ### Procédure de test et fonctionnement de `main.py` (`ParticleApp`)
#
# **`1. Tests d’interface utilisateur (UI)`**
#
# | ID  | Fonctionnalité                     | Procédure                                                                 | Données de test | Résultat attendu                                                                                                |
# | :-- | :--------------------------------- | :------------------------------------------------------------------------ | :-------------- | :-------------------------------------------------------------------------------------------------------------- |
# | 1  | Lancement de l'application         | Exécuter `main.py`                                                        | Aucune          | La fenêtre principale s'affiche sans erreur, avec titre, panneaux et onglets. Status bar indique "Prêt.".        |
# | 2  | Affichage section particules       | Vérifier la section "Gestion des Particules" à gauche                     | Aucune          | Champs Masse/Charge, boutons Ajouter/Construire/Raccourcis/Supprimer, et table Treeview visibles.                 |
# | 3  | Navigation entre onglets           | Cliquer sur les onglets "Magnétique", "Électrique", "Potentiel"             | Aucune          | Le contenu du panneau de contrôle change pour afficher les widgets spécifiques à chaque onglet, sans erreur.      |
# | 4  | Affichage widgets dynamiques (Mag) | Onglet Magnétique : Cocher/Décocher "Mode Dynamique"                      | Aucune          | Les entrées statiques (V0, Bz) ou les sliders/limites dynamiques (V0, Bz) s'affichent/se cachent correctement. |
# | 5  | Affichage widgets dynamiques (Elec)| Onglet Électrique : Cocher/Décocher "Mode Dynamique"                      | Aucune          | Les entrées statiques (V0, Potentiel) ou les sliders/limites dynamiques s'affichent/se cachent correctement.   |
# | 6  | Affichage widgets dynamiques (Pot) | Onglet Potentiel : Cocher/Décocher "Mode Dynamique"                       | Aucune          | Les entrées statiques (V0, Potentiel) ou les sliders/limites dynamiques s'affichent/se cachent correctement.   |
# | 7  | Affichage widgets incertitude (Elec)| Onglet Électrique : Cocher/Décocher "Afficher Incertitudes"               | Aucune          | Le cadre "Paramètres d'incertitude" s'affiche/se cache correctement.                                           |
# | 8  | Affichage widgets incertitude (Pot) | Onglet Potentiel : Cocher/Décocher "Afficher Incertitudes"                | Aucune          | Le cadre "Paramètres d'incertitude" s'affiche/se cache correctement.                                           |
# | 9  | Ouverture Constructeur Molécule    | Cliquer sur "Construire une Particule..."                                 | Aucune          | Une nouvelle fenêtre "Construire une Particule" s'ouvre (modale).                                              |
# | 10 | Défilement panneau contrôle      | Ajouter suffisamment de widgets (via onglets/options) pour dépasser la hauteur, utiliser la molette/scrollbar | Aucune          | Le panneau de contrôle défile correctement, la scrollbar apparaît/disparaît si besoin.                      |
# | 11 | Fermeture application            | Cliquer sur le bouton de fermeture de la fenêtre                          | Aucune          | Une boîte de dialogue demande confirmation. Si "OK", l'application se ferme proprement.                        |
#
# **`2. Tests fonctionnels : Gestion des particules`**
#
# | ID  | Fonctionnalité                      | Procédure                                                                                                | Données de test                                         | Résultat attendu                                                                                                  |
# | :-- | :---------------------------------- | :------------------------------------------------------------------------------------------------------- | :------------------------------------------------------ | :---------------------------------------------------------------------------------------------------------------- |
# | 1  | Ajout manuel valide                 | Entrer Masse=1, Charge=1, cliquer "Ajouter"                                                              | Masse=1.0, Charge=+1.0                                  | "Particule manuelle" (1.000 u, +1.00 e) ajoutée à la liste. Champs vidés. Status bar confirme.                     |
# | 2  | Ajout masse <= 0                    | Entrer Masse=0 (ou -1), Charge=1, cliquer "Ajouter"                                                      | Masse=0, Charge=1                                       | Message d'erreur "Masse doit être > 0.". Particule non ajoutée.                                                   |
# | 3  | Ajout charge == 0                   | Entrer Masse=1, Charge=0, cliquer "Ajouter"                                                              | Masse=1, Charge=0                                       | Message d'erreur "Charge ne peut pas être nulle...". Particule non ajoutée.                                       |
# | 4  | Ajout doublon                       | Ajouter (1u, +1e). Essayer d'ajouter (1u, +1e) à nouveau.                                                | Masse=1.0, Charge=+1.0 (deux fois)                      | Premier ajout OK. Second ajout : Message "Doublon". Particule non ajoutée une seconde fois. Status bar indique doublon. |
# | 5  | Ajout charge signe opposé           | Ajouter (1u, +1e). Essayer d'ajouter (2u, -1e).                                                         | Masse=2.0, Charge=-1.0                                  | Premier ajout OK. Second ajout : Message "Les particules doivent avoir des charges de même signe.". Non ajouté.   |
# | 6  | Ajout via raccourci (H⁺)            | Cliquer sur le bouton "H⁺"                                                                               | Aucune                                                  | "H(+1)" (1.008 u, +1.00 e) ajoutée à la liste. Status bar confirme.                                              |
# | 7  | Ajout via raccourci (doublon)       | Cliquer sur "H⁺" deux fois                                                                               | Aucune                                                  | Premier ajout OK. Second clic : Particule non ajoutée. Status bar indique "déjà présente".                         |
# | 8  | Ajout via constructeur (valide)     | Ouvrir constructeur, cliquer 'C', 'O', 'O', entrer Charge=-1, cliquer "Ajouter..."                       | C, O, O, Charge=-1                                      | Fenêtre constructeur se ferme. "CO₂(-1)" (44.009 u, -1.00 e) ajoutée à la liste. Status bar confirme.              |
# | 9  | Ajout via constructeur (vide)       | Ouvrir constructeur, cliquer "Ajouter..." sans sélectionner d'élément.                                   | Charge=1                                                | Message "Aucun Élément". Fenêtre reste ouverte. Particule non ajoutée.                                             |
# | 10 | Ajout via constructeur (charge invalide)| Ouvrir constructeur, cliquer 'H', entrer Charge="abc", cliquer "Ajouter..."                             | H, Charge="abc"                                         | Message "Erreur de Saisie". Fenêtre reste ouverte. Particule non ajoutée.                                         |
# | 11 | Utilisation constructeur (affichage)| Ouvrir constructeur, cliquer 'H', 'H', 'O'.                                                               | H, H, O                                                 | Le label "Particule construite" affiche "H₂O".                                                                    |
# | 12 | Utilisation constructeur (reset)    | Ouvrir constructeur, cliquer 'H', 'O', cliquer "Effacer".                                                 | H, O                                                    | Le label "Particule construite" affiche "(vide)".                                                                 |
# | 13 | Suppression sans sélection          | Cliquer "Supprimer Sélection" sans rien sélectionner dans la liste.                                      | Aucune                                                  | Message "Aucune Sélection". Rien n'est supprimé.                                                                  |
# | 14 | Suppression une particule           | Ajouter (1u, +1e). Sélectionner cette ligne. Cliquer "Supprimer Sélection".                              | Particule sélectionnée                                  | Particule supprimée de la liste et des données. Status bar confirme "1 particule(s) supprimée(s)".                 |
# | 15 | Suppression multiples particules    | Ajouter (1u, +1e), (2u, +1e). Sélectionner les deux lignes. Cliquer "Supprimer Sélection".                 | Deux particules sélectionnées                         | Boîte de dialogue demande confirmation. Si "Oui", particules supprimées. Status bar confirme "2 particule(s)...". |
#
# **`3. Tests fonctionnels : Déviation Magnétique (Onglet)`**
#
# | ID  | Fonctionnalité                     | Procédure                                                                           | Données de test                                  | Résultat attendu                                                                                              |
# | :-- | :--------------------------------- | :---------------------------------------------------------------------------------- | :----------------------------------------------- | :-------------------------------------------------------------------------------------------------------------- |
# | 1  | Simulation statique valide         | Ajouter (1u, +1e). Entrer V0=1e6, Bz=0.1, X détecteur=0.1. Cliquer "Tracer Simulation". | V0=1e6, Bz=0.1, Xdet=0.1                         | Graphique tracé dans le panneau de droite. Status bar indique "Tracé ... terminé.".                              |
# | 2  | Simulation statique (Bz=0)         | Ajouter (1u, +1e). Entrer V0=1e6, Bz=0, Xdet=0.1. Cliquer "Tracer Simulation".         | Bz=0                                             | Message d'erreur "Champ magnétique ne peut être nul.". Pas de tracé. Status bar indique erreur.                   |
# | 3  | Simulation statique (V0<=0)        | Ajouter (1u, +1e). Entrer V0=0, Bz=0.1, Xdet=0.1. Cliquer "Tracer Simulation".         | V0=0                                             | Message d'erreur "Vitesse initiale doit être > 0.". Pas de tracé. Status bar indique erreur.                    |
# | 4  | Simulation statique (Xdet<=0)      | Ajouter (1u, +1e). Entrer V0=1e6, Bz=0.1, Xdet=0. Cliquer "Tracer Simulation".         | Xdet=0                                           | Message d'erreur "X détecteur doit être positif.". Pas de tracé. Status bar indique erreur.                    |
# | 5  | Simulation statique (pas particule)| Cliquer "Tracer Simulation" sans particule ajoutée.                                   | Aucune particule                                 | Message "Aucune Particule". Graphique vide affiché. Status bar indique "Ajoutez des particules...".              |
# | 6  | Simulation dynamique (sliders)     | Ajouter (1u, +1e). Cocher "Mode Dynamique". Cliquer "Appliquer...". Bouger slider Bz. | Bz entre limites valides                         | Graphique se met à jour en temps réel. Label Bz mis à jour. Status bar indique "Tracé ... terminé.".           |
# | 7  | Simulation dynamique (limites inv) | Cocher "Mode Dynamique". Entrer Bz min=0.5, Bz max=0.1. Cliquer "Appliquer...".       | Bz min > Bz max                                  | Message d'erreur "Bz max doit être > Bz min.". Pas de tracé dynamique initial. Status bar indique erreur.        |
# | 8  | Maj Label Slider Bz                | Cocher "Mode Dynamique". Bouger slider Bz.                                          | Valeur du slider                                 | Le label à droite du slider Bz affiche la valeur formatée en T (ex: 0.123 T).                                    |
# | 9  | Maj Label Slider V0 (Mag)          | Cocher "Mode Dynamique". Bouger slider V0.                                          | Valeur du slider                                 | Le label à droite du slider V0 affiche la valeur formatée en m/s (ex: 5.50e+05 m/s).                             |
#
# **`4. Tests fonctionnels : Déviation Électrique (Onglet Standard)`**
#
# | ID  | Fonctionnalité                       | Procédure                                                                                           | Données de test                                      | Résultat attendu                                                                                                   |
# | :-- | :----------------------------------- | :-------------------------------------------------------------------------------------------------- | :--------------------------------------------------- | :----------------------------------------------------------------------------------------------------------------- |
# | 1  | Simulation statique valide           | Ajouter (1u, +1e). Entrer Angle=45, Dist=0.1, V0=1e5, Potentiel=-5000. Cliquer "Tracer Simulation".   | Angle=45, Dist=0.1, V0=1e5, Pot=-5000               | Graphique tracé. Status bar indique "Tracé électrique terminé.".                                                  |
# | 2  | Simulation statique (Angle invalide) | Ajouter (1u, +1e). Entrer Angle=100. Cliquer "Tracer Simulation".                                   | Angle=100                                            | Message d'erreur "Angle doit être > 0° et < 90°.". Pas de tracé.                                                  |
# | 3  | Simulation statique (Dist invalide)  | Ajouter (1u, +1e). Entrer Dist=0. Cliquer "Tracer Simulation".                                      | Dist=0                                               | Message d'erreur "Hauteur/Distance doit être > 0.". Pas de tracé.                                                 |
# | 4  | Simulation statique (V0 invalide)    | Ajouter (1u, +1e). Entrer V0=0. Cliquer "Tracer Simulation".                                        | V0=0                                                 | Message d'erreur "Vitesse initiale doit être > 0.". Pas de tracé.                                                 |
# | 5  | Simulation statique (pas particule)  | Cliquer "Tracer Simulation" sans particule ajoutée.                                                 | Aucune particule                                     | Message "Aucune Particule". Graphique vide. Status bar indique "Ajoutez des particules...".                       |
# | 6  | Simulation dynamique (sliders)       | Ajouter (1u, +1e). Cocher "Mode Dynamique". Cliquer "Appliquer...". Bouger slider Potentiel.        | Potentiel entre limites valides                      | Graphique mis à jour en temps réel. Label Potentiel mis à jour. Status bar OK.                                      |
# | 7  | Simulation dynamique (limites inv)   | Cocher "Mode Dynamique". Entrer Pot min=1000, Pot max=-1000. Cliquer "Appliquer...".                 | Pot min > Pot max                                    | Message d'erreur "Potentiel max doit être > Potentiel min.". Pas de tracé dynamique initial. Status bar erreur.       |
# | 8  | Simulation avec incertitudes (valide)| Ajouter (1u,+1e). Cocher "Afficher Incertitudes". Entrer valeurs valides. Cliquer "Tracer Simulation".| Incertitudes valides (ex: 1.0)                     | Graphique tracé avec couloirs d'incertitude (pointillés). Status bar indique "avec incertitude terminé.".          |
# | 9  | Simulation avec incertitudes (invalide)| Cocher "Afficher Incertitudes". Entrer "abc" pour ΔV0/V0. Cliquer "Tracer Simulation".                 | ΔV0/V0 = "abc"                                       | Message "Erreur Incertitude" (ou similaire). Pas de tracé (ou tracé sans incertitude si géré). Status bar erreur.      |
# | 10 | Maj Label Slider Potentiel (Elec)  | Cocher "Mode Dynamique". Bouger slider Potentiel.                                                 | Valeur du slider                                     | Le label à droite du slider Potentiel affiche la valeur formatée en V (ex: -5000.0 V).                            |
# | 11 | Maj Label Slider V0 (Elec)         | Cocher "Mode Dynamique". Bouger slider V0.                                                          | Valeur du slider                                     | Le label à droite du slider V0 affiche la valeur formatée en m/s (ex: 1.00e+05 m/s).                               |
#
# **`5. Tests fonctionnels : Déviation Électrique (Onglet Potentiel)`**
#
# | ID  | Fonctionnalité                       | Procédure                                                                                           | Données de test                                      | Résultat attendu                                                                                                   |
# | :-- | :----------------------------------- | :-------------------------------------------------------------------------------------------------- | :--------------------------------------------------- | :----------------------------------------------------------------------------------------------------------------- |
# | 1  | Simulation statique (une particule)  | Ajouter (1u, +1e). Entrer Angle=45, Dist=0.1, RefPot=0, V0=1e5, Potentiel=-5000. Cliquer "Tracer".    | Une particule, paramètres valides                  | Graphique tracé (devrait appeler `deviation.tracer_ensemble_trajectoires` actuellement). Status bar OK.             |
# | 2  | Simulation statique (multiples part) | Ajouter (1u, +1e), (2u, +1e). Cliquer "Tracer Simulation".                                          | Deux particules                                      | Message "Trop de particules". Pas de tracé. Status bar indique "Retirez des particules...".                         |
# | 3  | Simulation statique (pas particule)  | Cliquer "Tracer Simulation" sans particule ajoutée.                                                 | Aucune particule                                     | Message "Aucune Particule". Graphique vide. Status bar indique "Ajoutez des particules...".                       |
# | 4  | Simulation statique (param invalide) | Ajouter (1u, +1e). Entrer Angle=100. Cliquer "Tracer Simulation".                                   | Angle=100                                            | Message d'erreur "Angle doit être > 0° et < 90°.". Pas de tracé.                                                  |
# | 5  | Simulation dynamique (une particule) | Ajouter (1u, +1e). Cocher "Mode Dynamique". Cliquer "Appliquer...". Bouger slider Potentiel.        | Une particule, Potentiel entre limites valides     | Graphique mis à jour en temps réel. Label Potentiel mis à jour. Status bar OK.                                      |
# | 6  | Simulation dynamique (multiples part)| Ajouter (1u, +1e), (2u, +1e). Cocher "Mode Dynamique". Cliquer "Appliquer...".                       | Deux particules                                      | Message "Trop de particules". Pas de tracé dynamique initial. Status bar indique "Retirez des particules...".         |
# | 7  | Simulation avec incertitudes         | Ajouter (1u,+1e). Cocher "Afficher Incertitudes". Entrer valeurs valides. Cliquer "Tracer Simulation".| Une particule, Incertitudes valides                | Graphique tracé avec couloirs (devrait appeler `deviation.tracer_ensemble_trajectoires_avec_incertitudes`). Status bar OK. |
# | 8  | Maj Label Slider Potentiel (Pot)     | Ajouter (1u,+1e). Cocher "Mode Dynamique". Bouger slider Potentiel.                                 | Valeur du slider                                     | Le label à droite du slider Potentiel affiche la valeur formatée en V (ex: -5000.0 V).                            |
# | 9  | Maj Label Slider V0 (Pot)            | Ajouter (1u,+1e). Cocher "Mode Dynamique". Bouger slider V0.                                        | Valeur du slider                                     | Le label à droite du slider V0 affiche la valeur formatée en m/s (ex: 1.00e+05 m/s).                               |
